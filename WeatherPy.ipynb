# %% [markdown]
# # WeatherPy
# ---
# The notebook is the creation of a travel suggesting tool dependent on weather. The needs of the project are below.

# %%
#import the random module
import random

#import pandas for df management
import pandas as pd

# import numpy
import numpy as np

#import matplotlib for plotting funtionality
import matplotlib.pyplot as plt

# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# import citipy to get closest city from lat long
from citipy import citipy

# import the datetime module from the datetime library
from datetime import datetime

# Import the API key.
from config import weather_api_key

# Import the requests library.
import requests

import os

import time

# %% [markdown]
# First thing is to create a coordinate list.

# %%
# create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# Then we can translate those coordinates to a list of cities. There will be fewer cities than coordinates since some coordinates will be close to the same cities.

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 625

# %% [markdown]
# As long as we have a number over 500 for the length of cities we should be good. Now we can start the data retrieval process.

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hobart
# Processing Record 2 of Set 1 | nishihara
# Processing Record 3 of Set 1 | qaanaaq
# Processing Record 4 of Set 1 | marawi
# Processing Record 5 of Set 1 | upernavik
# Processing Record 6 of Set 1 | cape town
# Processing Record 7 of Set 1 | chapais
# Processing Record 8 of Set 1 | severo-kurilsk
# Processing Record 9 of Set 1 | atuona
# Processing Record 10 of Set 1 | jurm
# Processing Record 11 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 1 | san marcos de colon
# Processing Record 13 of Set 1 | makakilo city
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | saint-georges
# Processing Record 16 of Set 1 | bengkulu
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | labuhan
# Processing Record 19 of Set 1 | maceio
# Processing Record 20 of Set 1 | busselton
# Processing Record 21 of Set 1 | orta nova
# Processing Record 22 of Set 1 | bluff
# Processing Record 23 of Set 1 | danville
# Processing Record 24 of Set 1 | kapaa
# Processing Record 25 of Set 1 | saskylakh
# Processing Record 26 of Set 1 | mahebourg
# Processing Record 27 of Set 1 | chitral
# Processing Record 28 of Set 1 | valparaiso
# Processing Record 29 of Set 1 | jamestown
# Processing Record 30 of Set 1 | kapoeta
# Processing Record 31 of Set 1 | albany
# Processing Record 32 of Set 1 | tondano
# Processing Record 33 of Set 1 | road town
# Processing Record 34 of Set 1 | hilo
# Processing Record 35 of Set 1 | victoria
# Processing Record 36 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 37 of Set 1 | geraldton
# Processing Record 38 of Set 1 | bethanien
# Processing Record 39 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 1 | avarua
# Processing Record 41 of Set 1 | rikitea
# Processing Record 42 of Set 1 | vaini
# Processing Record 43 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 44 of Set 1 | todos santos
# Processing Record 45 of Set 1 | khatanga
# Processing Record 46 of Set 1 | marzuq
# Processing Record 47 of Set 1 | ponta do sol
# Processing Record 48 of Set 1 | faanui
# Processing Record 49 of Set 1 | sinnamary
# Processing Record 50 of Set 1 | puerto ayora
# Processing Record 1 of Set 2 | araguaina
# Processing Record 2 of Set 2 | zeya
# Processing Record 3 of Set 2 | kloulklubed
# Processing Record 4 of Set 2 | porto novo
# Processing Record 5 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record
# City not found. Skipping...
# Processing Record 1 of Set 5 | tamiahua
# Processing Record 2 of Set 5 | kudahuvadhoo
# Processing Record 3 of Set 5 | luwuk
# Processing Record 4 of Set 5 | takapau
# Processing Record 5 of Set 5 | rogun
# City not found. Skipping...
# Processing Record 6 of Set 5 | camacha
# Processing Record 7 of Set 5 | cobija
# Processing Record 8 of Set 5 | xuddur
# Processing Record 9 of Set 5 | odweyne
# Processing Record 10 of Set 5 | sorong
# Processing Record 11 of Set 5 | nouakchott
# Processing Record 12 of Set 5 | sur
# Processing Record 13 of Set 5 | luderitz
# Processing Record 14 of Set 5 | castro
# Processing Record 15 of Set 5 | lagoa
# Processing Record 16 of Set 5 | udachnyy
# Processing Record 17 of Set 5 | lompoc
# Processing Record 18 of Set 5 | kollam
# Processing Record 19 of Set 5 | pinhao
# Processing Record 20 of Set 5 | pangody
# Processing Record 21 of Set 5 | canberra
# Processing Record 22 of Set 5 | bilma
# Processing Record 23 of Set 5 | tiksi
# Processing Record 24 of Set 5 | kasama
# Processing Record 25 of Set 5 | aksarka
# Processing Record 26 of Set 5 | port elizabeth
# Processing Record 27 of Set 5 | cabo san lucas
# Processing Record 28 of Set 5 | manchester
# Processing Record 29 of Set 5 | katobu
# Processing Record 30 of Set 5 | pandan
# Processing Record 31 of Set 5 | yining
# Processing Record 32 of Set 5 | kiruna
# Processing Record 33 of Set 5 | arraial do cabo
# Processing Record 34 of Set 5 | vestmannaeyjar
# Processing Record 35 of Set 5 | komsomolskiy
# Processing Record 36 of Set 5 | ust-maya
# Processing Record 37 of Set 5 | nikolskoye
# Processing Record 38 of Set 5 | san patricio
# Processing Record 39 of Set 5 | moerai
# Processing Record 40 of Set 5 | iqaluit
# Processing Record 41 of Set 5 | ruston
# Processing Record 42 of Set 5 | saint-pierre
# Processing Record 43 of Set 5 | qaqortoq
# Processing Record 44 of Set 5 | lata
# Processing Record 45 of Set 5 | bernburg
# Processing Record 46 of Set 5 | issoudun
# Processing Record 47 of Set 5 | carndonagh
# Processing Record 48 of Set 5 | tacuarembo
# Processing Record 49 of Set 5 | temaraia
# City not found. Skipping...
# Processing Record 50 of Set 5 | teahupoo
# City not found. Skipping...
# Processing Record 1 of Set 6 | oranjemund
# Processing Record 2 of Set 6 | parras
# City not found. Skipping...
# Processing Record 3 of Set 6 | chokurdakh
# Processing Record 4 of Set 6 | dakar
# Processing Record 5 of Set 6 | grindavik
# Processing Record 6 of Set 6 | daru
# Processing Record 7 of Set 6 | galesong
# Processing Record 8 of Set 6 | camocim
# Processing Record 9 of Set 6 | edwardsville
# Processing Record 10 of Set 6 | lukovetskiy
# Processing Record 11 of Set 6 | westport
# Processing Record 12 of Set 6 | meulaboh
# Processing Record 13 of Set 6 | nantucket
# Processing Record 14 of Set 6 | najran
# Processing Record 15 of Set 6 | yulara
# Processing Record 16 of Set 6 | sambava
# Processing Record 17 of Set 6 | matay
# Processing Record 18 of Set 6 | salinopolis
# Processing Record 19 of Set 6 | college
# Processing Record 20 of Set 6 | punta alta
# Processing Record 21 of Set 6 | karauzyak
# City not found. Skipping...
# Processing Record 22 of Set 6 | leningradskiy
# Processing Record 23 of Set 6 | husavik
# Processing Record 24 of Set 6 | cayenne
# Processing Record 25 of Set 6 | veraval
# Processing Record 26 of Set 6 | ola
# Processing Record 27 of Set 6 | akyab
# Processing Record 28 of Set 6 | kodiak
# Processing Record 29 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 6 | saldanha
# Processing Record 31 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 6 | americus
# Processing Record 33 of Set 6 | tuatapere
# Processing Record 34 of Set 6 | norman wells
# Processing Record 35 of Set 6 | kirovskiy
# Processing Record 36 of Set 6 | george town
# Processing Record 37 of Set 6 | kez
# Processing Record 38 of Set 6 | tombouctou
# Processing Record 39 of Set 6 | touros
# Processing Record 40 of Set 6 | christchurch
# Processing Record 41 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 42 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 43 of Set 6 | goderich
# Processing Record 44 of Set 6 | sibolga
# Processing Record 45 of Set 6 | graham
# Processing Record 46 of Set 6 | san lawrenz
# Processing Record 47 of Set 6 | san jose
# Processing Record 48 of Set 6 | kabare
# Processing Record 49 of Set 6 | cidreira
# Processing Record 50 of Set 6 | la rioja
# Processing Record 1 of Set 7 | ulladulla
# Processing Record 2 of Set 7 | ijaki
# City not found. Skipping...
# Processing Record 3 of Set 7 | avera
# Processing Record 4 of Set 7 | limbang
# Processing Record 5 of Set 7 | boyolangu
# Processing Record 6 of Set 7 | clyde river
# Processing Record 7 of Set 7 | vardo
# Processing Record 8 of Set 7 | olafsvik
# Processing Record 9 of Set 7 | manono
# Processing Record 10 of Set 7 | lorengau
# Processing Record 11 of Set 7 | maragogi
# Processing Record 12 of Set 7 | vila do maio
# Processing Record 13 of Set 7 | ithaki
# Processing Record 14 of Set 7 | la asuncion
# Processing Record 15 of Set 7 | tyumentsevo
# Processing Record 16 of Set 7 | logrono
# Processing Record 17 of Set 7 | praia
# Processing Record 18 of Set 7 | kahului
# Processing Record 19 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 20 of Set 7 | masaguisi
# Processing Record 21 of Set 7 | inuvik
# Processing Record 22 of Set 7 | taoudenni
# Processing Record 23 of Set 7 | davila
# Processing Record 24 of Set 7 | am timan
# Processing Record 25 of Set 7 | bronnoysund
# Processing Record 26 of Set 7 | meadow lake
# Processing Record 27 of Set 7 | topolovgrad
# Processing Record 28 of Set 7 | tanhacu
# Processing Record 29 of Set 7 | jacksonville
# Processing Record 30 of Set 7 | alihe
# Processing Record 31 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 32 of Set 7 | poum
# Processing Record 33 of Set 7 | nome
# Processing Record 34 of Set 7 | andapa
# Processing Record 35 of Set 7 | moyale
# Processing Record 36 of Set 7 | chateauroux
# Processing Record 37 of Set 7 | hinton
# Processing Record 38 of Set 7 | ballina
# Processing Record 39 of Set 7 | kendallville
# Processing Record 40 of Set 7 | lebu
# Processing Record 41 of Set 7 | puerto asis
# Processing Record 42 of Set 7 | zyryanka
# Processing Record 43 of Set 7 | merauke
# Processing Record 44 of Set 7 | arman
# Processing Record 45 of Set 7 | dhidhdhoo
# Processing Record 46 of Set 7 | aquiraz
# Processing Record 47 of Set 7 | poso
# Processing Record 48 of Set 7 | bakel
# Processing Record 49 of Set 7 | narsaq
# Processing Record 50 of Set 7 | vung tau
# Processing Record 1 of Set 8 | havelock
# Processing Record 2 of Set 8 | yeppoon
# Processing Record 3 of Set 8 | bay-khaak
# Processing Record 4 of Set 8 | hobyo
# Processing Record 5 of Set 8 | banikoara
# Processing Record 6 of Set 8 | gangotri
# City not found. Skipping...
# Processing Record 7 of Set 8 | zhanaozen
# Processing Record 8 of Set 8 | ponta delgada
# Processing Record 9 of Set 8 | tigzirt
# Processing Record 10 of Set 8 | evensk
# Processing Record 11 of Set 8 | anadyr
# Processing Record 12 of Set 8 | buchanan
# Processing Record 13 of Set 8 | cockburn town
# Processing Record 14 of Set 8 | nargana
# Processing Record 15 of Set 8 | soyo
# Processing Record 16 of Set 8 | abashiri
# Processing Record 17 of Set 8 | souillac
# Processing Record 18 of Set 8 | cordele
# Processing Record 19 of Set 8 | takoradi
# Processing Record 20 of Set 8 | bac lieu
# Processing Record 21 of Set 8 | yenagoa
# Processing Record 22 of Set 8 | guerrero negro
# Processing Record 23 of Set 8 | brae
# Processing Record 24 of Set 8 | droylsden
# Processing Record 25 of Set 8 | ancud
# Processing Record 26 of Set 8 | bugiri
# Processing Record 27 of Set 8 | axim
# Processing Record 28 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 29 of Set 8 | port hardy
# Processing Record 30 of Set 8 | qax

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        Chapais  49.78  -74.85     68.00        94          90       10.29
# 1          Ancud -41.87  -73.82     44.01       100          20       10.29
# 2        Mataura -46.19  168.86     39.00        83          95        3.00
# 3  Saint Anthony  45.02  -93.22     88.00        51          20        3.29
# 4         Hobart -42.88  147.33     34.00        86          75        8.05
# 5    New Norfolk -42.78  147.06     33.01        92          57        2.28
# 6          Tabuk  17.42  121.44     74.97        89         100        3.62
# 7        Cayenne   4.93  -52.33     84.20        74           0        4.70
# 8         Albany  42.60  -73.97     84.00        55           5        8.50
# 9         Dikson  73.51   80.55     48.43        70           0       18.41
#
#   Country                 Date
# 0      CA  2020-07-07 21:51:27
# 1      CL  2020-07-07 21:51:28
# 2      NZ  2020-07-07 21:51:10
# 3      US  2020-07-07 21:51:28
# 4      AU  2020-07-07 21:50:34
# 5      AU  2020-07-07 21:51:28
# 6      PH  2020-07-07 21:51:28
# 7      GF  2020-07-07 21:51:29
# 8      US  2020-07-07 21:51:29
# 9      RU  2020-07-07 21:51:29

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]

city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#               City Country                 Date    Lat     Lng  Max Temp  \
# 0          Chapais      CA  2020-07-07 21:51:27  49.78  -74.85     68.00
# 1            Ancud      CL  2020-07-07 21:51:28 -41.87  -73.82     44.01
# 2          Mataura      NZ  2020-07-07 21:51:10 -46.19  168.86     39.00
# 3    Saint Anthony      US  2020-07-07 21:51:28  45.02  -93.22     88.00
# 4           Hobart      AU  2020-07-07 21:50:34 -42.88  147.33     34.00
# ..             ...     ...                  ...    ...     ...       ...
# 559            Bam      IR  2020-07-07 21:52:46  29.11   58.36     80.24
# 560            Voh      NC  2020-07-07 21:52:47 -20.97  164.70     71.08
# 561       La Palma      US  2020-07-07 21:52:47  33.85 -118.05     89.01
# 562         Panaba      MX  2020-07-07 21:52:47  21.28  -88.27     85.84
# 563       Kerouane      GN  2020-07-07 21:52:47   9.27   -9.02     71.92
#
#      Humidity  Cloudiness  Wind Speed
# 0          94          90       10.29
# 1         100          20       10.29
# 2          83          95        3.00
# 3          51          20        3.29
# 4          86          75        8.05
# ..        ...         ...         ...
# 559        23           7        4.38
# 560        64           1        5.86
# 561        48           1       10.29
# 562        76          60       14.56
# 563        93          81        3.09
#
# [564 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = os.path.join("Weather_Data","cities.csv")

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

# %%
# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.  
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):
    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
    
    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.title(title)
    plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       "Linear Regression on the Northern Hemisphere \n for Maximum Temperature", 'Max Temp',(10,40))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n for Maximum Temperature', 'Max Temp',(-50,85))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \n for % Humidity', '% Humidity',(40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n for % Humidity', '% Humidity',(-50,15))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
# Call the function
plot_linear_regression(x_values, y_values,
                   'Linear Regression on the Northern Hemisphere \n for % Cloudiness', '% Cloudiness',(10,55))

# %%
# Linear regression on the Northern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function
plot_linear_regression(x_values, y_values,
                   'Linear Regression on the Southern Hemisphere \n for % Cloudiness', '% Cloudiness',(10,55))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \n for Wind Speed', 'Wind Speed',(40,35))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n for Wind Speed', 'Wind Speed',(-50,35))
